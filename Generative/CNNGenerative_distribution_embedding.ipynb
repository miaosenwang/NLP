# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Convolution1D, Flatten, MaxPooling1D, Embedding
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
from nltk.tokenize import sent_tokenize
import numpy as np
import random
import sys
# Out:
# Using TensorFlow backend.

# %%
# load the text file into memory
file = open('../../Data/Books/sherlock.txt')
MAX_NB_WORDS = 8000
textSource = ['BOL ' + line + ' EOL' for line in sent_tokenize(file.read().lower().replace('\n', ' '))]
 

file.close()
print('corpus length:', len(textSource))
# Out:
# corpus length: 6925

# %%
textSource[0]
# Out:
# "BOL \ufeffproject gutenberg's the adventures of sherlock holmes, by arthur conan doyle  this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever. EOL"

# %%
# tokenize words and convert word sequence to digit sequence
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(textSource)

sequences = tokenizer.texts_to_sequences(textSource)
word_index = tokenizer.word_index
vocab_size = len(word_index) +1

# build a reverse look up: index -> word
index_word = dict()
for k,v in word_index.items():
    if not v in index_word:
        index_word[v] = k
        
print('sentences count:', len(sequences))
print('vocab size:', vocab_size)
# Out:
# sentences count: 6925
# vocab size: 8467

# %%
# build the training data by creating context-> next word paris. by shiftting x number of word per pair

min_length = 1
sentences = []
next_words = []
for i in range(0, len(sequences)):
    for j in range(min_length, len(sequences[i])-1): 
        sentences.append(sequences[i][0: j])
        next_words.append(sequences[i][j+1])

print('training sequences count:', len(sentences))
print('longest training sentence', len( max(sentences, key=len)))
# Out:
# training sequences count: 108593
# longest training sentence 105

# %%
# build training data
X = pad_sequences(sentences)
y = np.zeros((len(sentences), vocab_size), dtype=np.bool)
for i, sentence in enumerate(sentences):
    y[i, next_words[i]] = 1

sent_length = len(X[0])

# %%
model = Sequential()
model.add(Embedding(vocab_size, 100, input_length=sent_length))
model.add(Convolution1D(filters=20, kernel_size=5, activation='relu', padding='valid'))
model.add(MaxPooling1D(3))
model.add(Convolution1D(filters=20, kernel_size=5, activation='relu', padding='valid'))
model.add(MaxPooling1D(3))
model.add(Convolution1D(filters=20, kernel_size=5, activation='relu', padding='valid'))
model.add(MaxPooling1D(3))
model.add(Flatten())
model.add(Dense(vocab_size, activation='softmax'))
optimizer = RMSprop(lr=0.01)

model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds):
    preds = np.asarray(preds).astype('float64')
    exp_preds = np.exp(np.log(preds))
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def append_word(input, count, word_num):
    input[0][count] = word_num
    count += 1

# %%
def generate_sent(model):
    input = np.zeros((1, sent_length), dtype=np.float32)
    message = 'sherlock holmes'
    count =0
    append_word(input, count, word_index['bol'])
    append_word(input, count, word_index['sherlock'])
    append_word(input, count, word_index['holmes'])
    
    for i in range(0, 10):
        predict = model.predict(input)[0]
        next = sample(predict)

        input[0][count] = next
        count += 1
        
        message += ' '
        message += index_word[next]
        
        # start a new sentence when the current one ends
        if index_word[next] == 'eol':
            append_word(input, count, word_index['bol'])
            message += ' bol'

        print(message)

# %%
for iteration in range(1, 50):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y, batch_size=256, epochs=10)
    
    generate_sent(model)
model.save('StoryModelCNN.model')
# Out:
# --------------------------------------------------
# Iteration 1
# Epoch 1/10
# 108593/108593 [==============================] - 13s - loss: 6.5854
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.3802
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.4153
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.5426
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.6219
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.6685
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.6996
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.7215
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.7361
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.7479
# sherlock holmes it
# sherlock holmes it will
# sherlock holmes it will for
# sherlock holmes it will for a
# sherlock holmes it will for a faced
# sherlock holmes it will for a faced he
# sherlock holmes it will for a faced he follow
# sherlock holmes it will for a faced he follow i
# sherlock holmes it will for a faced he follow i in
# sherlock holmes it will for a faced he follow i in looked
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.7556
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.7625
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.7677
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.7726
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.7754
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.7795
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.7838
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.7865
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.7886
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.7888
# sherlock holmes card
# sherlock holmes card eol bol
# sherlock holmes card eol bol way
# sherlock holmes card eol bol way the
# sherlock holmes card eol bol way the face
# sherlock holmes card eol bol way the face into
# sherlock holmes card eol bol way the face into really
# sherlock holmes card eol bol way the face into really such
# sherlock holmes card eol bol way the face into really such the
# sherlock holmes card eol bol way the face into really such the information
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.7893
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.7918
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.7915
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.7929
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.7932
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.7961
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.7957
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.7981
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.7976
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.7981
# sherlock holmes eol bol
# sherlock holmes eol bol drawn
# sherlock holmes eol bol drawn must
# sherlock holmes eol bol drawn must clear
# sherlock holmes eol bol drawn must clear without
# sherlock holmes eol bol drawn must clear without you
# sherlock holmes eol bol drawn must clear without you rather
# sherlock holmes eol bol drawn must clear without you rather the
# sherlock holmes eol bol drawn must clear without you rather the a
# sherlock holmes eol bol drawn must clear without you rather the a am
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.7982
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.7979
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.7988
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.7997
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8008
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.7995
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8017
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8027
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8033
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8024
# sherlock holmes i
# sherlock holmes i as
# sherlock holmes i as case
# sherlock holmes i as case hands
# sherlock holmes i as case hands eol bol
# sherlock holmes i as case hands eol bol so
# sherlock holmes i as case hands eol bol so the
# sherlock holmes i as case hands eol bol so the the
# sherlock holmes i as case hands eol bol so the the the
# sherlock holmes i as case hands eol bol so the the the of
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8037
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8025
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8043
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8052
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8055
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8061
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8069
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8069
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8060
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8080
# sherlock holmes very
# sherlock holmes very the
# sherlock holmes very the writing
# sherlock holmes very the writing me
# sherlock holmes very the writing me the
# sherlock holmes very the writing me the there
# sherlock holmes very the writing me the there came
# sherlock holmes very the writing me the there came eol bol
# sherlock holmes very the writing me the there came eol bol than
# sherlock holmes very the writing me the there came eol bol than he
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8082
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8086
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8087
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8095
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8094
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8094
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8120
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8120
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8101
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8127
# sherlock holmes that
# sherlock holmes that a
# sherlock holmes that a like
# sherlock holmes that a like terms
# sherlock holmes that a like terms be
# sherlock holmes that a like terms be miss
# sherlock holmes that a like terms be miss after
# sherlock holmes that a like terms be miss after dear
# sherlock holmes that a like terms be miss after dear far
# sherlock holmes that a like terms be miss after dear far a
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8129
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8123
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8127
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8123
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8121
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8129
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8122
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8116
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8120
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8133
# sherlock holmes the
# sherlock holmes the to
# sherlock holmes the to the
# sherlock holmes the to the to
# sherlock holmes the to the to me
# sherlock holmes the to the to me things
# sherlock holmes the to the to me things been
# sherlock holmes the to the to me things been his
# sherlock holmes the to the to me things been his he
# sherlock holmes the to the to me things been his he of
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8139
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8153
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8155
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8164
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8152
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8164
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8168
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8164
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8163
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8178
# sherlock holmes he
# sherlock holmes he i
# sherlock holmes he i the
# sherlock holmes he i the simon
# sherlock holmes he i the simon as
# sherlock holmes he i the simon as eol bol
# sherlock holmes he i the simon as eol bol singular
# sherlock holmes he i the simon as eol bol singular then
# sherlock holmes he i the simon as eol bol singular then his
# sherlock holmes he i the simon as eol bol singular then his will
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8169
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8169
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8168
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8173
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8174
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8179
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8186
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8185
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8202
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8181
# sherlock holmes down
# sherlock holmes down it
# sherlock holmes down it struck
# sherlock holmes down it struck eol bol
# sherlock holmes down it struck eol bol ago
# sherlock holmes down it struck eol bol ago door
# sherlock holmes down it struck eol bol ago door that
# sherlock holmes down it struck eol bol ago door that violence
# sherlock holmes down it struck eol bol ago door that violence eol bol
# sherlock holmes down it struck eol bol ago door that violence eol bol was
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8210
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8198
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8202
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8195
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8187
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8177
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8188
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8189
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8183
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8181
# sherlock holmes mr
# sherlock holmes mr any
# sherlock holmes mr any was
# sherlock holmes mr any was take
# sherlock holmes mr any was take the
# sherlock holmes mr any was take the or
# sherlock holmes mr any was take the or think
# sherlock holmes mr any was take the or think eol bol
# sherlock holmes mr any was take the or think eol bol now
# sherlock holmes mr any was take the or think eol bol now as
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8196
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8196
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8212
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8221
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8216
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8214
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8196
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8192
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8205
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8199
# sherlock holmes eol bol
# sherlock holmes eol bol to
# sherlock holmes eol bol to to
# sherlock holmes eol bol to to heard
# sherlock holmes eol bol to to heard night
# sherlock holmes eol bol to to heard night he
# sherlock holmes eol bol to to heard night he to
# sherlock holmes eol bol to to heard night he to there
# sherlock holmes eol bol to to heard night he to there by
# sherlock holmes eol bol to to heard night he to there by have
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8202
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8216
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8199
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8202
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8215
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8204
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8197
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8191
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8203
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8200
# sherlock holmes have
# sherlock holmes have eol bol
# sherlock holmes have eol bol that
# sherlock holmes have eol bol that to
# sherlock holmes have eol bol that to day
# sherlock holmes have eol bol that to day said
# sherlock holmes have eol bol that to day said shall
# sherlock holmes have eol bol that to day said shall in
# sherlock holmes have eol bol that to day said shall in lay
# sherlock holmes have eol bol that to day said shall in lay what
#
# --------------------------------------------------
# Iteration 13
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8201
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8200
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8212
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8215
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8236
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8225
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8226
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8219
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8218
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8227
# sherlock holmes strange
# sherlock holmes strange eol bol
# sherlock holmes strange eol bol eol bol
# sherlock holmes strange eol bol eol bol to
# sherlock holmes strange eol bol eol bol to of
# sherlock holmes strange eol bol eol bol to of every
# sherlock holmes strange eol bol eol bol to of every afternoon
# sherlock holmes strange eol bol eol bol to of every afternoon out
# sherlock holmes strange eol bol eol bol to of every afternoon out in
# sherlock holmes strange eol bol eol bol to of every afternoon out in eol bol
#
# --------------------------------------------------
# Iteration 14
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8216
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8224
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8214
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8219
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8223
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8231
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8235
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8224
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8220
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8225
# sherlock holmes asked
# sherlock holmes asked in
# sherlock holmes asked in and
# sherlock holmes asked in and band
# sherlock holmes asked in and band for
# sherlock holmes asked in and band for the
# sherlock holmes asked in and band for the of
# sherlock holmes asked in and band for the of of
# sherlock holmes asked in and band for the of of his
# sherlock holmes asked in and band for the of of his an
#
# --------------------------------------------------
# Iteration 15
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8217
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8221
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8235
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8232
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8224
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8232
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8229
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8238
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8232
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8242
# sherlock holmes coming
# sherlock holmes coming see
# sherlock holmes coming see had
# sherlock holmes coming see had thought
# sherlock holmes coming see had thought seemed
# sherlock holmes coming see had thought seemed all
# sherlock holmes coming see had thought seemed all out
# sherlock holmes coming see had thought seemed all out his
# sherlock holmes coming see had thought seemed all out his course
# sherlock holmes coming see had thought seemed all out his course a
#
# --------------------------------------------------
# Iteration 16
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8233
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8241
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8229
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8230
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8226
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8246
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8245
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8226
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8226
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8226
# sherlock holmes them
# sherlock holmes them of
# sherlock holmes them of case
# sherlock holmes them of case found
# sherlock holmes them of case found is
# sherlock holmes them of case found is night
# sherlock holmes them of case found is night doing
# sherlock holmes them of case found is night doing is
# sherlock holmes them of case found is night doing is eol bol
# sherlock holmes them of case found is night doing is eol bol street
#
# --------------------------------------------------
# Iteration 17
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8243
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8257
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8258
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8262
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8249
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8235
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8234
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8257
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8242
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8261
# sherlock holmes went
# sherlock holmes went i
# sherlock holmes went i is
# sherlock holmes went i is singular
# sherlock holmes went i is singular business
# sherlock holmes went i is singular business now
# sherlock holmes went i is singular business now star
# sherlock holmes went i is singular business now star cleared
# sherlock holmes went i is singular business now star cleared card
# sherlock holmes went i is singular business now star cleared card secure
#
# --------------------------------------------------
# Iteration 18
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8251
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8242
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8248
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8248
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8251
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8257
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8245
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8249
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8257
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8247
# sherlock holmes eol bol
# sherlock holmes eol bol eol bol
# sherlock holmes eol bol eol bol he
# sherlock holmes eol bol eol bol he done
# sherlock holmes eol bol eol bol he done under
# sherlock holmes eol bol eol bol he done under into
# sherlock holmes eol bol eol bol he done under into shown
# sherlock holmes eol bol eol bol he done under into shown himself
# sherlock holmes eol bol eol bol he done under into shown himself to
# sherlock holmes eol bol eol bol he done under into shown himself to much
#
# --------------------------------------------------
# Iteration 19
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8244
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8232
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8255
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8249
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8255
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8266
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8266
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8252
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8257
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8268
# sherlock holmes the
# sherlock holmes the said
# sherlock holmes the said five
# sherlock holmes the said five eol bol
# sherlock holmes the said five eol bol that
# sherlock holmes the said five eol bol that eol bol
# sherlock holmes the said five eol bol that eol bol holder
# sherlock holmes the said five eol bol that eol bol holder read
# sherlock holmes the said five eol bol that eol bol holder read with
# sherlock holmes the said five eol bol that eol bol holder read with very
#
# --------------------------------------------------
# Iteration 20
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8260
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8260
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8265
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8263
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8256
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8244
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8245
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8257
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8273
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8259
# sherlock holmes sat
# sherlock holmes sat the
# sherlock holmes sat the the
# sherlock holmes sat the the it
# sherlock holmes sat the the it think
# sherlock holmes sat the the it think after
# sherlock holmes sat the the it think after could
# sherlock holmes sat the the it think after could to
# sherlock holmes sat the the it think after could to eol bol
# sherlock holmes sat the the it think after could to eol bol in
#
# --------------------------------------------------
# Iteration 21
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8266
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8259
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8285
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8270
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8266
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8260
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8273
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8263
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8265
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8257
# sherlock holmes this
# sherlock holmes this very
# sherlock holmes this very it
# sherlock holmes this very it could
# sherlock holmes this very it could and
# sherlock holmes this very it could and assistant
# sherlock holmes this very it could and assistant business
# sherlock holmes this very it could and assistant business to
# sherlock holmes this very it could and assistant business to second
# sherlock holmes this very it could and assistant business to second to
#
# --------------------------------------------------
# Iteration 22
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8269
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8272
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8270
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8265
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8272
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8266
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8262
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8262
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8264
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8261
# sherlock holmes be
# sherlock holmes be there
# sherlock holmes be there a
# sherlock holmes be there a at
# sherlock holmes be there a at eol bol
# sherlock holmes be there a at eol bol a
# sherlock holmes be there a at eol bol a was
# sherlock holmes be there a at eol bol a was must
# sherlock holmes be there a at eol bol a was must at
# sherlock holmes be there a at eol bol a was must at i
#
# --------------------------------------------------
# Iteration 23
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8250
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8250
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8253
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8259
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8274
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8280
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8262
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8254
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8256
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8270
# sherlock holmes your
# sherlock holmes your as
# sherlock holmes your as glanced
# sherlock holmes your as glanced in
# sherlock holmes your as glanced in think
# sherlock holmes your as glanced in think man
# sherlock holmes your as glanced in think man for
# sherlock holmes your as glanced in think man for to
# sherlock holmes your as glanced in think man for to i
# sherlock holmes your as glanced in think man for to i not
#
# --------------------------------------------------
# Iteration 24
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8278
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8285
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8284
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8280
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8264
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8262
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8264
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8263
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8267
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8281
# sherlock holmes not
# sherlock holmes not to
# sherlock holmes not to with
# sherlock holmes not to with is
# sherlock holmes not to with is can
# sherlock holmes not to with is can not
# sherlock holmes not to with is can not matter
# sherlock holmes not to with is can not matter during
# sherlock holmes not to with is can not matter during the
# sherlock holmes not to with is can not matter during the end
#
# --------------------------------------------------
# Iteration 25
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8293
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8279
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8284
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8285
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8286
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8281
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8277
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8268
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8269
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8277
# sherlock holmes eol bol
# sherlock holmes eol bol worn
# sherlock holmes eol bol worn down
# sherlock holmes eol bol worn down your
# sherlock holmes eol bol worn down your eol bol
# sherlock holmes eol bol worn down your eol bol that
# sherlock holmes eol bol worn down your eol bol that given
# sherlock holmes eol bol worn down your eol bol that given moment
# sherlock holmes eol bol worn down your eol bol that given moment i
# sherlock holmes eol bol worn down your eol bol that given moment i a
#
# --------------------------------------------------
# Iteration 26
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8257
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8273
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8275
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8267
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8271
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8270
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8287
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8273
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8284
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8281
# sherlock holmes by
# sherlock holmes by the
# sherlock holmes by the do
# sherlock holmes by the do he
# sherlock holmes by the do he offered
# sherlock holmes by the do he offered remarked
# sherlock holmes by the do he offered remarked country
# sherlock holmes by the do he offered remarked country eol bol
# sherlock holmes by the do he offered remarked country eol bol eol bol
# sherlock holmes by the do he offered remarked country eol bol eol bol you
#
# --------------------------------------------------
# Iteration 27
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8272
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8272
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8277
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8291
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8314
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8291
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8282
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8278
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8278
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8278
# sherlock holmes eol bol
# sherlock holmes eol bol two
# sherlock holmes eol bol two the
# sherlock holmes eol bol two the given
# sherlock holmes eol bol two the given a
# sherlock holmes eol bol two the given a and
# sherlock holmes eol bol two the given a and either
# sherlock holmes eol bol two the given a and either shall
# sherlock holmes eol bol two the given a and either shall enough
# sherlock holmes eol bol two the given a and either shall enough the
#
# --------------------------------------------------
# Iteration 28
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8287
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8283
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8284
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8269
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8285
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8282
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8284
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8281
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8295
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8292
# sherlock holmes with
# sherlock holmes with do
# sherlock holmes with do you
# sherlock holmes with do you day
# sherlock holmes with do you day and
# sherlock holmes with do you day and yet
# sherlock holmes with do you day and yet the
# sherlock holmes with do you day and yet the believe
# sherlock holmes with do you day and yet the believe a
# sherlock holmes with do you day and yet the believe a has
#
# --------------------------------------------------
# Iteration 29
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8300
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8287
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8284
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8294
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8295
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8284
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8285
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8284
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8282
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8277
# sherlock holmes way
# sherlock holmes way eol bol
# sherlock holmes way eol bol of
# sherlock holmes way eol bol of there
# sherlock holmes way eol bol of there from
# sherlock holmes way eol bol of there from eol bol
# sherlock holmes way eol bol of there from eol bol not
# sherlock holmes way eol bol of there from eol bol not to
# sherlock holmes way eol bol of there from eol bol not to has
# sherlock holmes way eol bol of there from eol bol not to has a
#
# --------------------------------------------------
# Iteration 30
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8277
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8273
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8271
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8280
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8297
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8305
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8310
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8307
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8303
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8298
# sherlock holmes to
# sherlock holmes to business
# sherlock holmes to business the
# sherlock holmes to business the could
# sherlock holmes to business the could the
# sherlock holmes to business the could the this
# sherlock holmes to business the could the this certainly
# sherlock holmes to business the could the this certainly not
# sherlock holmes to business the could the this certainly not with
# sherlock holmes to business the could the this certainly not with ran
#
# --------------------------------------------------
# Iteration 31
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8302
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8302
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8301
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8297
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8288
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8306
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8308
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8312
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8323
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8318
# sherlock holmes is
# sherlock holmes is all
# sherlock holmes is all at
# sherlock holmes is all at something
# sherlock holmes is all at something time
# sherlock holmes is all at something time path
# sherlock holmes is all at something time path the
# sherlock holmes is all at something time path the silence
# sherlock holmes is all at something time path the silence 'you
# sherlock holmes is all at something time path the silence 'you eol bol
#
# --------------------------------------------------
# Iteration 32
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8323
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8306
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8302
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8310
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8308
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8307
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8313
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8314
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8308
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8301
# sherlock holmes he
# sherlock holmes he use
# sherlock holmes he use to
# sherlock holmes he use to would
# sherlock holmes he use to would my
# sherlock holmes he use to would my save
# sherlock holmes he use to would my save its
# sherlock holmes he use to would my save its as
# sherlock holmes he use to would my save its as to
# sherlock holmes he use to would my save its as to we
#
# --------------------------------------------------
# Iteration 33
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8296
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8299
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8298
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8313
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8313
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8307
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8323
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8321
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8318
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8309
# sherlock holmes him
# sherlock holmes him take
# sherlock holmes him take see
# sherlock holmes him take see and
# sherlock holmes him take see and put
# sherlock holmes him take see and put his
# sherlock holmes him take see and put his the
# sherlock holmes him take see and put his the me
# sherlock holmes him take see and put his the me home
# sherlock holmes him take see and put his the me home last
#
# --------------------------------------------------
# Iteration 34
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8306
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8323
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8308
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8320
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8320
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8320
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8314
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8298
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8308
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8306
# sherlock holmes eol bol
# sherlock holmes eol bol 1
# sherlock holmes eol bol 1 like
# sherlock holmes eol bol 1 like up
# sherlock holmes eol bol 1 like up pounds
# sherlock holmes eol bol 1 like up pounds from
# sherlock holmes eol bol 1 like up pounds from colonel
# sherlock holmes eol bol 1 like up pounds from colonel ever
# sherlock holmes eol bol 1 like up pounds from colonel ever the
# sherlock holmes eol bol 1 like up pounds from colonel ever the small
#
# --------------------------------------------------
# Iteration 35
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8313
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8307
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8317
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8322
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8324
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8302
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8305
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8314
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8295
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8321
# sherlock holmes was
# sherlock holmes was my
# sherlock holmes was my and
# sherlock holmes was my and gave
# sherlock holmes was my and gave train
# sherlock holmes was my and gave train go
# sherlock holmes was my and gave train go not
# sherlock holmes was my and gave train go not the
# sherlock holmes was my and gave train go not the roof
# sherlock holmes was my and gave train go not the roof the
#
# --------------------------------------------------
# Iteration 36
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8328
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8324
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8322
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8330
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8336
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8320
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8324
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8321
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8335
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8330
# sherlock holmes you
# sherlock holmes you quite
# sherlock holmes you quite to
# sherlock holmes you quite to a
# sherlock holmes you quite to a away
# sherlock holmes you quite to a away should
# sherlock holmes you quite to a away should must
# sherlock holmes you quite to a away should must as
# sherlock holmes you quite to a away should must as ever
# sherlock holmes you quite to a away should must as ever which
#
# --------------------------------------------------
# Iteration 37
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8323
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8325
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8314
# Epoch 4/10
# ...
# sherlock holmes would all spoke took he the been he my above
#
# --------------------------------------------------
# Iteration 38
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8327
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8325
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8331
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8334
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8325
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8333
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8335
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8326
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8340
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8334
# sherlock holmes you
# sherlock holmes you pocket
# sherlock holmes you pocket face
# sherlock holmes you pocket face remarked
# sherlock holmes you pocket face remarked seen
# sherlock holmes you pocket face remarked seen is
# sherlock holmes you pocket face remarked seen is to
# sherlock holmes you pocket face remarked seen is to eol bol
# sherlock holmes you pocket face remarked seen is to eol bol news
# sherlock holmes you pocket face remarked seen is to eol bol news sound
#
# --------------------------------------------------
# Iteration 39
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8331
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8328
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8331
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8330
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8348
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8349
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8325
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8324
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8330
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8319
# sherlock holmes colonel
# sherlock holmes colonel with
# sherlock holmes colonel with seen
# sherlock holmes colonel with seen not
# sherlock holmes colonel with seen not face
# sherlock holmes colonel with seen not face the
# sherlock holmes colonel with seen not face the the
# sherlock holmes colonel with seen not face the the with
# sherlock holmes colonel with seen not face the the with shall
# sherlock holmes colonel with seen not face the the with shall the
#
# --------------------------------------------------
# Iteration 40
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8312
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8323
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8322
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8329
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8319
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8314
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8315
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8324
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8333
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8331
# sherlock holmes table
# sherlock holmes table but
# sherlock holmes table but i
# sherlock holmes table but i old
# sherlock holmes table but i old how
# sherlock holmes table but i old how business
# sherlock holmes table but i old how business father
# sherlock holmes table but i old how business father no
# sherlock holmes table but i old how business father no eol bol
# sherlock holmes table but i old how business father no eol bol for
#
# --------------------------------------------------
# Iteration 41
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8314
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8313
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8329
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8324
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8335
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8327
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8313
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8330
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8321
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8332
# sherlock holmes and
# sherlock holmes and would
# sherlock holmes and would that
# sherlock holmes and would that a
# sherlock holmes and would that a that
# sherlock holmes and would that a that last
# sherlock holmes and would that a that last he
# sherlock holmes and would that a that last he to
# sherlock holmes and would that a that last he to must
# sherlock holmes and would that a that last he to must how
#
# --------------------------------------------------
# Iteration 42
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8344
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8340
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8334
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8338
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8336
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8325
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8322
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8316
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8326
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8347
# sherlock holmes her
# sherlock holmes her read
# sherlock holmes her read would
# sherlock holmes her read would we
# sherlock holmes her read would we the
# sherlock holmes her read would we the square
# sherlock holmes her read would we the square of
# sherlock holmes her read would we the square of a
# sherlock holmes her read would we the square of a to
# sherlock holmes her read would we the square of a to kind
#
# --------------------------------------------------
# Iteration 43
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8340
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8341
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8358
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8342
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8358
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8358
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8345
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8345
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8344
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8351
# sherlock holmes the
# sherlock holmes the have
# sherlock holmes the have table
# sherlock holmes the have table seems
# sherlock holmes the have table seems answered
# sherlock holmes the have table seems answered so
# sherlock holmes the have table seems answered so me
# sherlock holmes the have table seems answered so me the
# sherlock holmes the have table seems answered so me the lost
# sherlock holmes the have table seems answered so me the lost two
#
# --------------------------------------------------
# Iteration 44
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8340
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8330
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8346
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8355
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8351
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8343
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8343
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8332
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8337
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8342
# sherlock holmes made
# sherlock holmes made don't
# sherlock holmes made don't his
# sherlock holmes made don't his do
# sherlock holmes made don't his do hands
# sherlock holmes made don't his do hands eol bol
# sherlock holmes made don't his do hands eol bol may
# sherlock holmes made don't his do hands eol bol may soon
# sherlock holmes made don't his do hands eol bol may soon and
# sherlock holmes made don't his do hands eol bol may soon and come
#
# --------------------------------------------------
# Iteration 45
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8331
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8330
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8336
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8343
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8343
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8349
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8349
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8340
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8343
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8338
# sherlock holmes as
# sherlock holmes as as
# sherlock holmes as as any
# sherlock holmes as as any had
# sherlock holmes as as any had not
# sherlock holmes as as any had not point
# sherlock holmes as as any had not point such
# sherlock holmes as as any had not point such during
# sherlock holmes as as any had not point such during the
# sherlock holmes as as any had not point such during the father
#
# --------------------------------------------------
# Iteration 46
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8334
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8336
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8332
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8345
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8340
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8348
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8352
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8347
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8342
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8335
# sherlock holmes when
# sherlock holmes when court
# sherlock holmes when court that
# sherlock holmes when court that three
# sherlock holmes when court that three about
# sherlock holmes when court that three about past
# sherlock holmes when court that three about past thick
# sherlock holmes when court that three about past thick i
# sherlock holmes when court that three about past thick i and
# sherlock holmes when court that three about past thick i and i
#
# --------------------------------------------------
# Iteration 47
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8336
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8335
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8336
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8342
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8351
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8358
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8355
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8352
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8348
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8360
# sherlock holmes eol bol
# sherlock holmes eol bol eol bol
# sherlock holmes eol bol eol bol the
# sherlock holmes eol bol eol bol the letters
# sherlock holmes eol bol eol bol the letters eol bol
# sherlock holmes eol bol eol bol the letters eol bol here
# sherlock holmes eol bol eol bol the letters eol bol here to
# sherlock holmes eol bol eol bol the letters eol bol here to last
# sherlock holmes eol bol eol bol the letters eol bol here to last to
# sherlock holmes eol bol eol bol the letters eol bol here to last to my
#
# --------------------------------------------------
# Iteration 48
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8360
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8357
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8353
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8360
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8334
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8331
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8331
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8344
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8345
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8352
# sherlock holmes much
# sherlock holmes much father
# sherlock holmes much father my
# sherlock holmes much father my of
# sherlock holmes much father my of eol bol
# sherlock holmes much father my of eol bol of
# sherlock holmes much father my of eol bol of place
# sherlock holmes much father my of eol bol of place in
# sherlock holmes much father my of eol bol of place in and
# sherlock holmes much father my of eol bol of place in and not
#
# --------------------------------------------------
# Iteration 49
# Epoch 1/10
# 108593/108593 [==============================] - 9s - loss: 6.8347
# Epoch 2/10
# 108593/108593 [==============================] - 9s - loss: 6.8354
# Epoch 3/10
# 108593/108593 [==============================] - 9s - loss: 6.8351
# Epoch 4/10
# 108593/108593 [==============================] - 9s - loss: 6.8363
# Epoch 5/10
# 108593/108593 [==============================] - 9s - loss: 6.8343
# Epoch 6/10
# 108593/108593 [==============================] - 9s - loss: 6.8355
# Epoch 7/10
# 108593/108593 [==============================] - 9s - loss: 6.8367
# Epoch 8/10
# 108593/108593 [==============================] - 9s - loss: 6.8368
# Epoch 9/10
# 108593/108593 [==============================] - 9s - loss: 6.8353
# Epoch 10/10
# 108593/108593 [==============================] - 9s - loss: 6.8358
# sherlock holmes her
# sherlock holmes her hard
# sherlock holmes her hard him
# sherlock holmes her hard him round
# sherlock holmes her hard him round he
# sherlock holmes her hard him round he am
# sherlock holmes her hard him round he am might
# sherlock holmes her hard him round he am might to
# sherlock holmes her hard him round he am might to of
# sherlock holmes her hard him round he am might to of have
